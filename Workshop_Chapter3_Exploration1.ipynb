# %% [markdown]
# # UNIFORM DISTRIBUTION

# %%
# import matplotlib
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# import seaborn
import seaborn as sns
sns.set(rc={'figure.figsize':(8,5)})

# %%
# import uniform distribution
from scipy.stats import uniform

# %%
# random numbers from uniform distribution
n = 10000
start = 10
width = 20
data_uniform = uniform.rvs(size=n, loc = start, scale=width)

# %%
print(data_uniform)
# Out:
# [22.84545679 23.72512681 16.88078467 ... 14.2069903  21.90492317
#  25.12696453]

# %%
ax = sns.distplot(data_uniform,
                  bins=100)
ax.set(xlabel='Uniform Distribution ', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'Uniform Distribution '), Text(0, 0.5, 'Frequency')]

# %%
def mean(x): 
    return sum(x) / len(x)

# %%
# mu = (a+b)/2
mean(data_uniform)
# Out:
# 20.083181230287003

# %%
def de_mean(x):
    """translate x by subtracting its mean (so the result has mean 0)"""
    x_bar = mean(x)
    return [x_i - x_bar for x_i in x]

# %%
de_mean(data_uniform)
# Out:
# [2.7622755580277882,
#  3.6419455774233427,
#  -3.2023965584874965,
#  6.324230158483857,
#  -5.184828182264162,
#  -6.267287058172252,
#  -6.713049721361823,
#  2.250680046397889,
#  -5.039084942950321,
#  -1.9998859957639041,
#  0.7878421502157806,
#  1.1603494450948872,
#  8.39802633282369,
#  -5.288155729803229,
#  -8.411401658270506,
#  -4.09637684846402,
#  3.779158743585594,
#  6.303118563834083,
#  1.7000970351941476,
#  0.7793644288493837,
#  1.7595117703056289,
#  -2.778176080576216,
#  9.059171531223601,
#  -8.950109289126589,
#  -4.939853671733003,
#  -2.9642277029289943,
#  8.828818996759729,
#  -5.095051185699138,
#  -6.412806076432407,
#  7.2988402594411035,
#  0.027322321135692107,
#  -4.964151778706286,
#  -8.760948023432984,
#  4.407504138371582,
#  -6.292418946349018,
#  3.2127430773345935,
#  8.863859110144446,
#  2.051725909595852,
#  3.5847887662081988,
#  -9.218007648597156,
#  5.906239789552906,
#  -5.582560140278247,
#  -3.684666098964737,
# ...

# %%
def dot(v, w):
    """v_1 * w_1 + ... + v_n * w_n"""
    return sum(v_i * w_i for v_i, w_i in zip(v, w))

# %%
def sum_of_squares(v):
    """v_1 * v_1 + ... + v_n * v_n"""
    return dot(v, v)

# %%
def variance(x):
    """assumes x has at least two elements"""
    n = len(x)
    deviations = de_mean(x)
    return sum_of_squares(deviations) / (n - 1)

# %%
variance(data_uniform)
# Out:
# 33.5688437447411

# %%
import math
def standard_deviation(x):
    return math.sqrt(variance(x))

# %%
# sigma = sqrt((b-a)^2/12)
standard_deviation(data_uniform)
# Out:
# 5.793862592842628

# %%
prob = 1/(30-10)
print(prob)
# Out:
# 0.05

# %%
from scipy.stats import norm

mean = 20.084093979751227
sd = 5.760217929444366

print(norm(loc = mean , scale = sd).pdf(-1000))
print(norm(loc = mean , scale = sd).pdf(-5))
print(norm(loc = mean , scale = sd).pdf(5))
print(norm(loc = mean , scale = sd).pdf(10))
print(norm(loc = mean , scale = sd).pdf(15))
print(norm(loc = mean , scale = sd).pdf(20))
print(norm(loc = mean , scale = sd).pdf(25))
print(norm(loc = mean , scale = sd).pdf(30))
print(norm(loc = mean , scale = sd).pdf(35))
print(norm(loc = mean , scale = sd).pdf(40))
print(norm(loc = mean , scale = sd).pdf(45))
print(norm(loc = mean , scale = sd).pdf(1000))
# Out:
# 0.0
# 5.2795217261859045e-06
# 0.0022459585098249814
# 0.014961246791213103
# 0.04691468813733904
# 0.06925081195614363
# 0.048118922636562374
# 0.01573917302028452
# 0.002423387778136184
# 0.00017564625971639542
# 5.99280143812584e-06
# 0.0

# %% [markdown]
# # Normal Distribution

# %%
from scipy.stats import norm
# generate random numbers from N(0,1)
data_normal = norm.rvs(size=10000,loc=0,scale=1)

# %%
ax = sns.distplot(data_normal,
                  bins=100)
ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'Normal Distribution'), Text(0, 0.5, 'Frequency')]

# %%
def mean(x): 
    return sum(x) / len(x)

# %%
mean(data_normal)
# Out:
# -0.004953200711322097

# %%
variance(data_normal)
# Out:
# 1.0012653306303416

# %%
standard_deviation(data_normal)
# Out:
# 1.0006324653089873

# %%
from scipy.stats import norm

mean = -0.004624188626787543
sd = 0.9967193842582559

print(norm(loc = mean , scale = sd).cdf(1000))
print(norm(loc = mean , scale = sd).cdf(500))
print(norm(loc = mean , scale = sd).cdf(100))
print(norm(loc = mean , scale = sd).cdf(10))
print(norm(loc = mean , scale = sd).cdf(4))
print(norm(loc = mean , scale = sd).cdf(2))
print(norm(loc = mean , scale = sd).cdf(0))
print(norm(loc = mean , scale = sd).cdf(-2))
print(norm(loc = mean , scale = sd).cdf(-4))
print(norm(loc = mean , scale = sd).cdf(-10))
print(norm(loc = mean , scale = sd).cdf(-100))
print(norm(loc = mean , scale = sd).cdf(-500))
print(norm(loc = mean , scale = sd).cdf(-1000))
# Out:
# 1.0
# 1.0
# 1.0
# 1.0
# 0.9999706286197146
# 0.9778490059530767
# 0.5018508496644518
# 0.022645408625930716
# 3.05494246690177e-05
# 5.7249870511226755e-24
# 0.0
# 0.0
# 0.0

# %%
mean = -0.004624188626787543
sd = 0.9967193842582559

cdf_upper_limit = norm(loc = mean , scale = sd).cdf(2)
cdf_lower_limit = norm(loc = mean , scale = sd).cdf(-2)
 
prob = cdf_upper_limit - cdf_lower_limit
print(prob)
# Out:
# 0.955203597327146

# %%
mean = -0.004624188626787543
sd = 0.9967193842582559

cdf_upper_limit = norm(loc = mean , scale = sd).cdf(0)
cdf_lower_limit = norm(loc = mean , scale = sd).cdf(0)
 
prob = cdf_upper_limit - cdf_lower_limit
print(prob)
# Out:
# 0.0

# %%
mean = -0.004624188626787543
sd = 0.9967193842582559

cdf_upper_limit = norm(loc = mean , scale = sd).cdf(1)
cdf_lower_limit = norm(loc = mean , scale = sd).cdf(-1)
 
prob = cdf_upper_limit - cdf_lower_limit
print(prob)
# Out:
# 0.6842745141143647

# %%
mean = -0.004624188626787543
sd = 0.9967193842582559

cdf_upper_limit = norm(loc = mean , scale = sd).cdf(4)
cdf_lower_limit = norm(loc = mean , scale = sd).cdf(-4)
 
prob = cdf_upper_limit - cdf_lower_limit
print(prob)
# Out:
# 0.9999400791950456

# %%
mean = -0.004624188626787543
sd = 0.9967193842582559

cdf_upper_limit = norm(loc = mean , scale = sd).cdf(10)
cdf_lower_limit = norm(loc = mean , scale = sd).cdf(-10)
 
prob = cdf_upper_limit - cdf_lower_limit
print(prob)
# Out:
# 1.0

# %%
import numpy as np
def find_prob(x,mu,sigma):
    p = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp(-(x - mu)**2 / (2 * sigma**2))
    return p

# %%
print(find_prob(0,mean,sd))
print(find_prob(2,mean,sd))
print(find_prob(-2,mean,sd))
# Out:
# 0.4002510569030008
# 0.052963093044887645
# 0.05395843506550088

# %%
print(norm(loc = mean , scale = sd).pdf(0))
print(norm(loc = mean , scale = sd).pdf(2))
print(norm(loc = mean , scale = sd).pdf(-2))
# Out:
# 0.4002510569030007
# 0.05296309304488767
# 0.05395843506550088

# %% [markdown]
# # Z-SCORE

# %%
#z = (x-mu)/sigma -> distance of data-point from the mean

# %%
x = [-3,-2,-1,0,1,2,3]
y = [-4,-2,-1,0,1,2,4]
for i in y:
    z = (i-mean)/sd
    print(z)
# Out:
# -4.008526245675971
# -2.001943418465913
# -0.9986520048608833
# 0.004639408744145973
# 1.0079308223491752
# 2.0112222359542047
# 4.017805063164263

# %%
import numpy as np

ax = plt.gca()
ax.spines['top'].set_color('none')
ax.spines['left'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['bottom'].set_position('zero')
plt.xlim(-np.pi, np.pi)
plt.plot(x, y)
plt.title("Curve plotted using the given points")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
